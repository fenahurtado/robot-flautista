# %%
import mido
import json
from datetime import datetime

# %%
notes_alone = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]
notes = [i + str(j) for j in range(8) for i in notes_alone]
notes[38]
# Out:
# 'D3'

# %%
mid = mido.MidiFile('bee2.mid')
note = 0
time = 0
i = 0
fingers = []
for i, track in enumerate(mid.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        if track.name == "Melody":
            if i > 20:
                print(msg)
            i += 1
            if msg.type == 'note_on':
                time += msg.time
                note = msg.note - 24
                if note < 
                i += 1
            if msg.type == 'note_off':
                time += msg.time
                d = {
                    "note": notes[note],
                    "time": time/1000*2,
                    "type": 2
                }
                fingers.append(d)
                time = 0
# Out:
# Track 0:
# Track 1: Melody
# note_off channel=0 note=86 velocity=90 time=96
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=90 time=96
# note_on channel=0 note=84 velocity=100 time=0
# note_off channel=0 note=84 velocity=90 time=96
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=90 time=96
# note_on channel=0 note=84 velocity=100 time=0
# note_off channel=0 note=84 velocity=90 time=96
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=90 time=96
# note_on channel=0 note=82 velocity=100 time=0
# note_off channel=0 note=82 velocity=90 time=96
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=90 time=96
# note_on channel=0 note=80 velocity=100 time=0
# note_off channel=0 note=80 velocity=90 time=96
# note_on channel=0 note=79 velocity=100 time=0
# note_off channel=0 note=79 velocity=90 time=96
# note_on channel=0 note=78 velocity=100 time=0
# ...

# %%
len(fingers)
# Out:
# 788

# %%
init_pos = {
        "offset": -2.5,
        "r": 6.0,
        "theta": 47.0,
        "type": 0
    }
phrase = []

# %%
data = {'init_pos': init_pos, 'phrase': phrase, 'fingers': fingers, 'timestamp': datetime.now().strftime("%d/%m/%Y %H:%M:%S")}
path = "C:/Users/ferna/Dropbox/UC/Magister/robot-flautista/exercises/bumblebee_completo.json"
with open(path, 'w') as file:
    json.dump(data, file, indent=4, sort_keys=True)
